# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime, timedelta
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

# %%
df= pd.read_csv("/content/Copper_Set.xlsx - Result 1.csv")
df
# Out:
#                                          id   item_date  quantity tons  \
# 0      EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0      54.151139
# 1      4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0     768.024839
# 2      E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0     386.127949
# 3      F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0     202.411065
# 4      4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0     785.526262
# ...                                     ...         ...            ...
# 16851  68C637A0-0836-4C18-BEBB-BCA6757EAE05  20210312.0      25.058291
# 16852  6BA19491-A382-4EBC-923B-713239EEC817  20210312.0      94.891116
# 16853  536118F5-17B3-4130-B721-5BC4E34D3627  20210312.0      56.054345
# 16854  BB3004F9-DB04-47F3-BC56-649ADBC2A10A  20210312.0      92.689823
# 16855            719DAB19-8362-4268-A1F0-EB         NaN            NaN
#
#          customer  country status item type  application  thickness   width  \
# 0      30156308.0     28.0    Won         W         10.0       2.00  1500.0
# 1      30202938.0     25.0    Won         W         41.0       0.80  1210.0
# 2      30153963.0     30.0    Won        WI         28.0       0.38   952.0
# 3      30349574.0     32.0    Won         S         59.0       2.30  1317.0
# 4      30211560.0     28.0    Won         W         10.0       4.00  2000.0
# ...           ...      ...    ...       ...          ...        ...     ...
# 16851  30205825.0     25.0    Won         S         10.0       1.50  1510.0
# 16852  30393641.0     39.0   Lost         W         10.0       6.80  1255.0
# 16853  30218705.0     25.0    Won         W         41.0       0.55  1240.0
# 16854  30393641.0     39.0   Lost         W         10.0      11.80  1080.0
# 16855         NaN      NaN    NaN       NaN          NaN        NaN     NaN
#
#                                    material_ref   product_ref  delivery date  \
# 0                                   DEQ1 S460MC  1.670799e+09     20210701.0
# 1      0000000000000000000000000000000000104991  1.668702e+09     20210401.0
# 2                                      S0380700  6.283770e+05     20210101.0
# 3                       DX51D+ZM310MAO 2.3X1317  1.668702e+09     20210101.0
# 4                               2_S275JR+AR-CL1  6.406650e+05     20210301.0
# ...                                         ...           ...            ...
# 16851                              DX51D+ZM MAE  1.668702e+09     20210701.0
# 16852                                       NaN  6.406650e+05     20210701.0
# 16853  0000000000000000000000000000000001006410  6.119930e+05     20210401.0
# 16854                                       NaN  6.406650e+05     20210701.0
# 16855                                       NaN           NaN            NaN
#
#        selling_price
# 0             854.00
# 1            1047.00
# 2             644.33
# 3             768.00
# 4             577.00
# ...              ...
# 16851        1006.00
# 16852         964.00
# 16853        1119.00
# 16854         964.00
# 16855            NaN
#
# [16856 rows x 14 columns]

# %%
#checking the null values in this dataframe
df.isnull().sum()
# Out:
# id                  1
# item_date           1
# quantity tons       1
# customer            1
# country             1
# status              1
# item type           1
# application         1
# thickness           1
# width               1
# material_ref     7521
# product_ref         1
# delivery date       1
# selling_price       1
# dtype: int64

# %%
#checking the unique values of the all columns

for i in df.columns:
  print(i,":",df[i].nunique())
# Out:
# id : 16855
# item_date : 20
# quantity tons : 16855
# customer : 615
# country : 16
# status : 8
# item type : 6
# application : 26
# thickness : 361
# width : 827
# material_ref : 4079
# product_ref : 26
# delivery date : 19
# selling_price : 1792

# %%
df["quantity tons"]= pd.to_numeric(df["quantity tons"],errors="coerce")
df["item_date_1"]= pd.to_datetime(df["item_date"],format="%Y%m%d",errors="coerce").dt.date
df["delivery_date_1"]= pd.to_datetime(df["delivery date"],format="%Y%m%d",errors="coerce").dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16856 entries, 0 to 16855
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               16855 non-null  object
#  1   item_date        16855 non-null  float64
#  2   quantity tons    16855 non-null  float64
#  3   customer         16855 non-null  float64
#  4   country          16855 non-null  float64
#  5   status           16855 non-null  object
#  6   item type        16855 non-null  object
#  7   application      16855 non-null  float64
#  8   thickness        16855 non-null  float64
#  9   width            16855 non-null  float64
#  10  material_ref     9335 non-null   object
#  11  product_ref      16855 non-null  float64
#  12  delivery date    16855 non-null  float64
#  13  selling_price    16855 non-null  float64
#  14  item_date_1      16854 non-null  object
#  15  delivery_date_1  16854 non-null  object
# dtypes: float64(10), object(6)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# id                    1
# item_date             1
# quantity tons         1
# customer              1
# country               1
# status                1
# item type             1
# application           1
# thickness             1
# width                 1
# material_ref       7521
# product_ref           1
# delivery date         1
# selling_price         1
# item_date_1           2
# delivery_date_1       2
# dtype: int64

# %%
#removing the "00000" datas in the "material_ref" column
df["material_ref"]=df["material_ref"].apply(lambda x: np.nan if str(x).startswith("00000") else x)

# %%
df.isnull().sum()
# Out:
# id                    1
# item_date             1
# quantity tons         1
# customer              1
# country               1
# status                1
# item type             1
# application           1
# thickness             1
# width                 1
# material_ref       9465
# product_ref           1
# delivery date         1
# selling_price         1
# item_date_1           2
# delivery_date_1       2
# dtype: int64

# %%
df.drop(columns=["id","material_ref"],inplace=True)

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# item_date      16855.0  2.021031e+07  2.005234e+03  1.995000e+07
# quantity tons  16855.0  1.022338e+02  4.346836e+02  1.494114e-02
# customer       16855.0  3.023653e+07  7.219113e+04  3.014772e+07
# country        16855.0  4.298724e+01  2.332142e+01  2.500000e+01
# application    16855.0  2.588312e+01  1.745988e+01  2.000000e+00
# thickness      16855.0  2.731753e+00  1.941709e+01  1.800000e-01
# width          16855.0  1.303036e+03  2.453778e+02  1.000000e+00
# product_ref    16855.0  5.187498e+08  7.406125e+08  6.117280e+05
# delivery date  16855.0  2.021124e+07  7.779262e+04  2.019070e+07
# selling_price  16855.0  6.912511e+03  7.702567e+05 -1.160000e+03
#
#                         25%           50%           75%           max
# item_date      2.021032e+07  2.021032e+07  2.021032e+07  2.021040e+07
# quantity tons  1.373273e+01  3.162418e+01  7.131576e+01  2.030029e+04
# customer       3.019726e+07  3.020582e+07  3.028116e+07  3.040772e+07
# country        2.600000e+01  2.800000e+01  7.700000e+01  1.130000e+02
# application    1.000000e+01  1.500000e+01  4.100000e+01  9.900000e+01
# thickness      7.500000e-01  1.750000e+00  3.000000e+00  2.500000e+03
# width          1.178500e+03  1.250000e+03  1.500000e+03  2.150000e+03
# product_ref    6.283770e+05  6.406650e+05  1.668702e+09  1.721130e+09
# delivery date  2.021050e+07  2.021070e+07  2.021070e+07  3.031010e+07
# selling_price  8.840000e+02  9.840000e+02  1.107515e+03  1.000009e+08

# %%
df["quantity tons"]= df["quantity tons"].apply(lambda x: np.nan if x<=0 else x)
df["selling_price"]= df["selling_price"].apply(lambda x: np.nan if x<=0 else x)

# %%
df.nunique()
# Out:
# item_date             20
# quantity tons      16855
# customer             615
# country               16
# status                 8
# item type              6
# application           26
# thickness            361
# width                827
# product_ref           26
# delivery date         19
# selling_price       1790
# item_date_1           19
# delivery_date_1       18
# dtype: int64

# %%
df.isnull().sum()
# Out:
# item_date          1
# quantity tons      1
# customer           1
# country            1
# status             1
# item type          1
# application        1
# thickness          1
# width              1
# product_ref        1
# delivery date      1
# selling_price      3
# item_date_1        2
# delivery_date_1    2
# dtype: int64

# %%
df["item_date_1"].fillna(df["item_date_1"].mode().iloc[0],inplace=True)
df["delivery_date_1"].fillna(df["delivery_date_1"].mode().iloc[0],inplace=True)
df["status"].fillna(df["status"].mode().iloc[0],inplace=True)
df["item_date"]. fillna(df["item_date"].mode().iloc[0],inplace=True)
df["delivery date"]. fillna(df["delivery date"].mode().iloc[0],inplace=True)



df.isnull().sum()
# Out:
# item_date          0
# quantity tons      1
# customer           1
# country            1
# status             0
# item type          1
# application        1
# thickness          1
# width              1
# product_ref        1
# delivery date      0
# selling_price      3
# item_date_1        0
# delivery_date_1    0
# dtype: int64

# %%
df["quantity tons"].fillna(df["quantity tons"].median(),inplace=True)
df["customer"].fillna(df["customer"].median(),inplace=True)
df["country"].fillna(df["country"].median(),inplace=True)
df["application"].fillna(df["application"].median(),inplace=True)
df["thickness"].fillna(df["thickness"].median(),inplace=True)
df["selling_price"].fillna(df["selling_price"].median(),inplace=True)
df["width"].fillna(df["width"].median(),inplace=True)
df["product_ref"].fillna(df["product_ref"].median,inplace=True)
df["item type"].fillna(df["item type"].median,inplace=True)
df.isnull().sum()
# Out:
# item_date          0
# quantity tons      0
# customer           0
# country            0
# status             0
# item type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery date      0
# selling_price      0
# item_date_1        0
# delivery_date_1    0
# dtype: int64

# %%
df.head()
# Out:
#     item_date  quantity tons    customer  country  status item type  \
# 0  20210401.0      54.151139  30156308.0     28.0       1         W
# 1  20210401.0     768.024839  30202938.0     25.0       1         W
# 2  20210401.0     386.127949  30153963.0     30.0       1        WI
# 3  20210401.0     202.411065  30349574.0     32.0       1         S
# 4  20210401.0     785.526262  30211560.0     28.0       1         W
#
#    application  thickness   width   product_ref  delivery date  selling_price  \
# 0         10.0       2.00  1500.0  1670798778.0     20210701.0         854.00
# 1         41.0       0.80  1210.0  1668701718.0     20210401.0        1047.00
# 2         28.0       0.38   952.0      628377.0     20210101.0         644.33
# 3         59.0       2.30  1317.0  1668701718.0     20210101.0         768.00
# 4         10.0       4.00  2000.0      640665.0     20210301.0         577.00
#
#   item_date_1 delivery_date_1
# 0  2021-04-01      2021-07-01
# 1  2021-04-01      2021-04-01
# 2  2021-04-01      2021-01-01
# 3  2021-04-01      2021-01-01
# 4  2021-04-01      2021-03-01

# %%
df["status"].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered'], dtype=object)

# %%
df["status"]= df["status"].map({'Won':1, 'Draft':2, 'To be approved':3, 'Lost':0, 'Not lost for AM':4,
                                'Wonderful':5, 'Revised':6, 'Offered':7, 'Offerable':8})

# %%
df["item type"]= OrdinalEncoder().fit_transform(df[["item type"]])
df["item type"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _unique_python(values, return_inverse, return_counts)
#     172
# --> 173         uniques = sorted(uniques_set)
#     174         uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'method' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-b4ff6cb372ee> in <cell line: 1>()
# ----> 1 df["item type"]= OrdinalEncoder().fit_transform(df[["item type"]])
#       2 df["item type"]
#       3
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
#     880             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#    1301
#    1302         # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1303         self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    1304
#    1305         cardinalities = [len(categories) for categories in self.categories_]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown, force_all_finite, return_counts)
#      91
#      92             if self.categories == "auto":
# ---> 93                 result = _unique(Xi, return_counts=return_counts)
#      94                 if return_counts:
#      95                     cats, counts = result
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _unique(values, return_inverse, return_counts)
#      39     """
#      40     if values.dtype == object:
# ---> 41         return _unique_python(
#      42             values, return_inverse=return_inverse, return_counts=return_counts
#      43         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_encode.py in _unique_python(values, return_inverse, return_counts)
#     176     except TypeError:
#     177         types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 178         raise TypeError(
#     179             "Encoders require their input to be uniformly "
#     180             f"strings or numbers. Got {types}"
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['method', 'str']
